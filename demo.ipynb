# %% [markdown]
# # Demo notebook (§3.1 notebook cell, §3.8 inventory)
# Select the `.venv` kernel, then Run All.

# %%
import sys
print('Kernel interpreter:', sys.executable)  # must be inside .venv

# %%
# §3.8 framework query
import torch
print('torch', torch.__version__)
print('CUDA:', torch.cuda.is_available())
print('MPS:', torch.backends.mps.is_available())
